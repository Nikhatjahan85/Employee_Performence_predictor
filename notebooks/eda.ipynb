# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../data/employee_data.csv")

print(df.head())

sns.countplot(x='performance', data=df)
plt.show()

sns.histplot(df['salary'], kde=True)
plt.show()

sns.boxplot(x='performance', y='training_hours', data=df)
plt.show()
# Out:
#    age  experience department  salary  training_hours  projects_completed  \
# 0   50           1         IT   22719              12                   2
# 1   36           4         IT   42890              24                   9
# 2   29           4      Sales   97236               1                  16
# 3   42           5         IT   56509              34                  13
# 4   40          18         IT   62534               6                   9
#
#    attendance performance
# 0    0.961479         Low
# 1    0.777008      Medium
# 2    0.899588      Medium
# 3    0.940106      Medium
# 4    0.898799      Medium
